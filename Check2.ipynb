# %%
from ipynb.fs.defs.NN578hw5_Modified_Network import Network as network
from ipynb.fs.defs.NN578hw5_Modified_Network import loadCSV
from ipynb.fs.defs.NN578hw5_Modified_Network import QuadraticCost as QuadraticCost
from ipynb.fs.defs.NN578hw5_Modified_Network import Sigmoid as Sigmoid
from ipynb.fs.defs.NN578hw5_Modified_Network import Softmax as Softmax
from ipynb.fs.defs.NN578hw5_Modified_Network import Tanh as Tanh
from ipynb.fs.defs.NN578hw5_Modified_Network import ReLU as ReLU
from ipynb.fs.defs.NN578hw5_Modified_Network import LeakyReLU as LeakyReLU
from ipynb.fs.defs.NN578hw5_Modified_Network import CrossEntropyCost as CrossEntropyCost
from ipynb.fs.defs.NN578hw5_Modified_Network import LogLikelihood as LogLikelihood
import numpy as np
import pandas as pd

# %%
def displayResults(trainCost, trainAccuracy, testCost, testAccuracy):
    '''Function to display cost and accuracy results.'''
    
    #Convert a corrent_count to an accuracy percentage
    trainAccuracy = [accuracy / trainSize for accuracy in trainAccuracy]
    if len(testCost) > 0:
        #Convert a corrent_count to an accuracy percentage
        testAccuracy = [accuracy / testSize for accuracy in testAccuracy]
        res = pd.DataFrame(list(zip(trainCost, trainAccuracy, testCost, testAccuracy)),
                         columns = ['trainCost', 'trainAccuracy', 'testCost', 'testAccuracy'])
    else:
        res = pd.DataFrame(list(zip(train_cost, train_acc)),
                         columns = ['trainCost', 'trainAccuracy'])

    return res

# %%
#Load the iris train-test (separate) data files
irisTrain = loadCSV('iris-train-2.csv', 4, 3)
irisTest = loadCSV('iris-test-2.csv', 4, 3)

trainSize = len(irisTrain)
testSize = len(irisTest)

# %% [markdown]
# ### Experiment Out-C-1.txt

# %%
net1 = network.loadNetwork("iris-423.dat")
net1.set_modelParameters(cost=CrossEntropyCost, actHidden=Sigmoid, actOutput=Sigmoid)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net1.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    2.002196       0.333333  2.002243      0.333333
# 1    1.943619       0.333333  1.943673      0.333333
# 2    1.927285       0.333333  1.927337      0.333333
# 3    1.921016       0.333333  1.921082      0.333333
# 4    1.915906       0.333333  1.916043      0.333333
# 5    1.906507       0.333333  1.906913      0.333333
# 6    1.879229       0.333333  1.880613      0.333333
# 7    1.810508       0.333333  1.812951      0.333333
# 8    1.729821       0.666667  1.731632      0.666667
# 9    1.663903       0.666667  1.665606      0.666667
# 10   1.610357       0.666667  1.612705      0.666667
# 11   1.563669       0.666667  1.566806      0.666667
# 12   1.521549       0.666667  1.525341      0.666667
# 13   1.483243       0.666667  1.487526      0.666667
# 14   1.448333       0.666667  1.452969      0.666667
# 15   1.416485       0.666667  1.421364      0.666667
# ...

# %% [markdown]
# ### Experiment Out-C-2.txt

# %%
net2 = network.loadNetwork("iris-423.dat")
net2.set_modelParameters(cost=CrossEntropyCost, actHidden=Sigmoid, actOutput=Softmax)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net2.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    1.986701       0.333333  1.986722      0.333333
# 1    1.948911       0.333333  1.948911      0.333333
# 2    1.940007       0.333333  1.939987      0.333333
# 3    1.934935       0.333333  1.934920      0.333333
# 4    1.925780       0.333333  1.925901      0.333333
# 5    1.890867       0.333333  1.892089      0.333333
# 6    1.738627       0.400000  1.742223      0.400000
# 7    1.576116       0.666667  1.578931      0.666667
# 8    1.473465       0.666667  1.477511      0.666667
# 9    1.397451       0.666667  1.402594      0.666667
# 10   1.337653       0.666667  1.343368      0.666667
# 11   1.289928       0.666667  1.295854      0.666667
# 12   1.251366       0.666667  1.257281      0.666667
# 13   1.219804       0.666667  1.225578      0.666667
# 14   1.193637       0.666667  1.199195      0.666667
# 15   1.171667       0.666667  1.176970      0.666667
# ...

# %% [markdown]
# ### Experiment Out-C-3.txt

# %%
net3 = network.loadNetwork("iris-423.dat")
net3.set_modelParameters(cost=LogLikelihood, actHidden=Sigmoid, actOutput=Softmax)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net3.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    1.155591       0.333333  1.155661      0.333333
# 1    1.122715       0.333333  1.122763      0.333333
# 2    1.113785       0.333333  1.113817      0.333333
# 3    1.110381       0.333333  1.110407      0.333333
# 4    1.107699       0.333333  1.107737      0.333333
# 5    1.103746       0.333333  1.103846      0.333333
# 6    1.095186       0.333333  1.095527      0.333333
# 7    1.070114       0.333333  1.071358      0.333333
# 8    1.006211       0.333333  1.008593      0.333333
# 9    0.932931       0.666667  0.934693      0.666667
# 10   0.876997       0.666667  0.878384      0.666667
# 11   0.834727       0.666667  0.836365      0.666667
# 12   0.800362       0.666667  0.802443      0.666667
# 13   0.771033       0.666667  0.773498      0.666667
# 14   0.745577       0.666667  0.748316      0.666667
# 15   0.723337       0.666667  0.726252      0.666667
# ...

# %% [markdown]
# ### Experiement Out-C-4.txt

# %%
net4 = network.loadNetwork("iris-423.dat")
net4.set_modelParameters(cost=LogLikelihood, actHidden=ReLU, actOutput=Softmax)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net4.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    1.107051       0.333333  1.110724      0.311111
# 1    1.099879       0.333333  1.099915      0.333333
# 2    1.099615       0.333333  1.099652      0.333333
# 3    1.101120       0.333333  1.101158      0.333333
# 4    1.102686       0.333333  1.102724      0.333333
# 5    1.103884       0.333333  1.103923      0.333333
# 6    1.104705       0.333333  1.104743      0.333333
# 7    1.105237       0.333333  1.105276      0.333333
# 8    1.105572       0.333333  1.105611      0.333333
# 9    1.105780       0.333333  1.105819      0.333333
# 10   1.105908       0.333333  1.105947      0.333333
# 11   1.105986       0.333333  1.106025      0.333333
# 12   1.106033       0.333333  1.106072      0.333333
# 13   1.106062       0.333333  1.106101      0.333333
# 14   1.106080       0.333333  1.106119      0.333333
# 15   1.106090       0.333333  1.106129      0.333333
# ...

# %% [markdown]
# ### Experiement Out-C-4-2.txt

# %%
net4_2 = network.loadNetwork("iris-423.dat")
net4_2.set_modelParameters(cost=LogLikelihood, actHidden=LeakyReLU(alpha=0.3), actOutput=Softmax)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net4_2.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    0.770709       0.666667  0.788936      0.666667
# 1    0.550256       0.666667  0.553437      0.666667
# 2    0.513816       0.666667  0.508307      0.666667
# 3    0.487540       0.666667  0.474151      0.666667
# 4    0.476624       0.666667  0.457027      0.666667
# 5    1.848895       0.619048  1.688083      0.577778
# 6    1.966663       0.628571  1.771517      0.577778
# 7    1.890529       0.628571  1.680897      0.577778
# 8    1.859975       0.628571  1.637018      0.577778
# 9    1.793077       0.628571  1.558632      0.600000
# 10   1.800117       0.628571  1.552908      0.600000
# 11   1.769090       0.638095  1.510551      0.600000
# 12   1.727498       0.638095  1.458063      0.622222
# 13   1.684068       0.647619  1.403940      0.644444
# 14   1.641500       0.647619  1.350476      0.644444
# 15   1.589977       0.647619  1.289223      0.644444
# ...

# %% [markdown]
# ### Experiement Out-C-5.txt

# %%
net5 = network.loadNetwork("iris-423.dat")
net5.set_modelParameters(cost=QuadraticCost, actHidden=Tanh, actOutput=Sigmoid)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net5.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    0.386007       0.333333  0.385998      0.333333
# 1    0.364923       0.333333  0.364921      0.333333
# 2    0.352133       0.333333  0.352132      0.333333
# 3    0.344731       0.333333  0.344729      0.333333
# 4    0.340487       0.333333  0.340482      0.333333
# 5    0.338033       0.333333  0.338025      0.333333
# 6    0.336591       0.333333  0.336581      0.333333
# 7    0.335728       0.333333  0.335715      0.333333
# 8    0.335199       0.333333  0.335182      0.333333
# 9    0.334861       0.333333  0.334841      0.333333
# 10   0.334628       0.333333  0.334606      0.333333
# 11   0.334448       0.333333  0.334422      0.333333
# 12   0.334279       0.333333  0.334250      0.333333
# 13   0.334088       0.333333  0.334055      0.333333
# 14   0.333831       0.333333  0.333796      0.333333
# 15   0.333433       0.333333  0.333399      0.333333
# ...

# %% [markdown]
# ### Experiement Out-C-5-2.txt

# %%
net5_2 = network.loadNetwork("iris-423.dat")
net5_2.set_modelParameters(cost=QuadraticCost, actHidden=Tanh, actOutput=Tanh)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net5_2.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Error: Tanh cannot be used for output layer.  Changing to Sigmoid!
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    0.386007       0.333333  0.385998      0.333333
# 1    0.364923       0.333333  0.364921      0.333333
# 2    0.352133       0.333333  0.352132      0.333333
# 3    0.344731       0.333333  0.344729      0.333333
# 4    0.340487       0.333333  0.340482      0.333333
# 5    0.338033       0.333333  0.338025      0.333333
# 6    0.336591       0.333333  0.336581      0.333333
# 7    0.335728       0.333333  0.335715      0.333333
# 8    0.335199       0.333333  0.335182      0.333333
# 9    0.334861       0.333333  0.334841      0.333333
# 10   0.334628       0.333333  0.334606      0.333333
# 11   0.334448       0.333333  0.334422      0.333333
# 12   0.334279       0.333333  0.334250      0.333333
# 13   0.334088       0.333333  0.334055      0.333333
# 14   0.333831       0.333333  0.333796      0.333333
# ...

# %% [markdown]
# ### Experiement Out-C-6.txt

# %%
net6 = network.loadNetwork("iris-423.dat")
net6.set_compileParameters(regularization = 'L2', lmbda = 1.0)
net6.set_modelParameters(cost=CrossEntropyCost, actHidden=Sigmoid, actOutput=Sigmoid)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net6.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    2.069454       0.333333  2.163083      0.333333
# 1    2.007900       0.333333  2.096655      0.333333
# 2    1.989590       0.333333  2.075092      0.333333
# 3    1.981230       0.333333  2.064166      0.333333
# 4    1.973148       0.333333  2.053927      0.333333
# 5    1.957314       0.333333  2.036506      0.333333
# 6    1.913040       0.333333  1.991925      0.333333
# 7    1.835354       0.333333  1.914126      0.355556
# 8    1.767143       0.666667  1.846708      0.666667
# 9    1.715778       0.666667  1.798094      0.666667
# 10   1.672832       0.666667  1.759010      0.666667
# 11   1.634748       0.666667  1.725270      0.666667
# 12   1.600481       0.666667  1.695607      0.666667
# 13   1.569418       0.666667  1.669310      0.666667
# 14   1.540991       0.666667  1.645743      0.666667
# 15   1.514496       0.666667  1.624163      0.666667
# ...

# %% [markdown]
# ### Experiement Out-C-6-2.txt

# %%
net6_2 = network.loadNetwork("iris-423.dat")
net6_2.set_compileParameters(regularization = 'L2', lmbda = 1.0)
net6_2.set_modelParameters(cost=LogLikelihood, actHidden=LeakyReLU(alpha=0.3), actOutput=Softmax)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net6_2.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    0.827327       0.666667  0.921692      0.666667
# 1    0.611085       0.666667  0.694898      0.666667
# 2    0.577657       0.666667  0.655179      0.666667
# 3    0.554937       0.666667  0.626138      0.666667
# 4    0.560111       0.666667  0.628348      0.666667
# 5    1.799738       0.619048  1.748249      0.577778
# 6    1.882129       0.628571  1.806457      0.577778
# 7    1.861704       0.619048  1.782775      0.577778
# 8    1.877991       0.619048  1.794190      0.577778
# 9    1.873781       0.619048  1.786409      0.577778
# 10   1.860203       0.628571  1.769617      0.577778
# 11   1.842491       0.628571  1.749280      0.577778
# 12   1.838060       0.628571  1.741255      0.577778
# 13   1.834922       0.628571  1.734565      0.577778
# 14   1.840101       0.628571  1.735551      0.577778
# 15   1.834713       0.628571  1.726899      0.577778
# ...

# %% [markdown]
# ### Experiement Out-C-7.txt

# %%
net7 = network.loadNetwork("iris-423.dat")
net7.set_compileParameters(regularization = 'L1', lmbda = 1.0)
net7.set_modelParameters(cost=CrossEntropyCost, actHidden=Sigmoid, actOutput=Sigmoid)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net7.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    2.110464       0.333333  2.259471      0.333333
# 1    2.047328       0.333333  2.190278      0.333333
# 2    2.027634       0.333333  2.166237      0.333333
# 3    2.018783       0.333333  2.154530      0.333333
# 4    2.012109       0.333333  2.146745      0.333333
# 5    1.999379       0.333333  2.134167      0.333333
# 6    1.964696       0.333333  2.103490      0.333333
# 7    1.895360       0.333333  2.039641      0.333333
# 8    1.828586       0.666667  1.977365      0.666667
# 9    1.776054       0.666667  1.929227      0.666667
# 10   1.731926       0.666667  1.889364      0.666667
# 11   1.692317       0.666667  1.853788      0.666667
# 12   1.656013       0.666667  1.821265      0.666667
# 13   1.622436       0.666667  1.791205      0.666667
# 14   1.591670       0.666667  1.764429      0.666667
# 15   1.563105       0.666667  1.739787      0.666667
# ...

# %% [markdown]
# ### Experiement Out-C-7-2.txt

# %%
net7_2 = network.loadNetwork("iris-423.dat")
net7_2.set_compileParameters(lmbda = 1.0)
net7_2.set_modelParameters(cost=CrossEntropyCost, actHidden=Sigmoid, actOutput=Sigmoid)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net7_2.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    2.002196       0.333333  2.002243      0.333333
# 1    1.943619       0.333333  1.943673      0.333333
# 2    1.927285       0.333333  1.927337      0.333333
# 3    1.921016       0.333333  1.921082      0.333333
# 4    1.915906       0.333333  1.916043      0.333333
# 5    1.906507       0.333333  1.906913      0.333333
# 6    1.879229       0.333333  1.880613      0.333333
# 7    1.810508       0.333333  1.812951      0.333333
# 8    1.729821       0.666667  1.731632      0.666667
# 9    1.663903       0.666667  1.665606      0.666667
# 10   1.610357       0.666667  1.612705      0.666667
# 11   1.563669       0.666667  1.566806      0.666667
# 12   1.521549       0.666667  1.525341      0.666667
# 13   1.483243       0.666667  1.487526      0.666667
# 14   1.448333       0.666667  1.452969      0.666667
# 15   1.416485       0.666667  1.421364      0.666667
# ...

# %% [markdown]
# ### Experiement Out-C-8.txt

# %%
net8 = network.loadNetwork("iris4-20-7-3.dat")
net8.set_compileParameters(dropoutPercent = 0.3)
net8.set_modelParameters(cost=CrossEntropyCost, actHidden=Sigmoid, actOutput=Softmax)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net8.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    1.929504       0.333333  1.929462      0.333333
# 1    1.944791       0.333333  1.944927      0.333333
# 2    1.928749       0.333333  1.928670      0.333333
# 3    1.933287       0.333333  1.933115      0.333333
# 4    1.949628       0.333333  1.949737      0.333333
# 5    1.960771       0.333333  1.960809      0.333333
# 6    1.929513       0.333333  1.929396      0.333333
# 7    1.950277       0.333333  1.950404      0.333333
# 8    1.940327       0.333333  1.940478      0.333333
# 9    1.924926       0.333333  1.924894      0.333333
# 10   1.930533       0.333333  1.930540      0.333333
# 11   1.938652       0.333333  1.938607      0.333333
# 12   1.934287       0.333333  1.934306      0.333333
# 13   1.942058       0.333333  1.942016      0.333333
# 14   1.944457       0.333333  1.944445      0.333333
# 15   1.937830       0.333333  1.937745      0.333333
# ...

# %% [markdown]
# ### Experiement Out-C-9.txt

# %%
net9 = network.loadNetwork("iris4-20-7-3.dat")
net9.set_compileParameters(dropoutPercent = 0.3)
net9.set_modelParameters(cost=LogLikelihood, actHidden=ReLU, actOutput=Softmax)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net9.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    1.086979       0.333333  1.084162      0.333333
# 1    1.103939       0.333333  1.103939      0.333333
# 2    1.013831       0.333333  1.004451      0.333333
# 3    1.043946       0.333333  1.032899      0.333333
# 4    1.126954       0.333333  1.138346      0.333333
# 5    0.997001       0.333333  0.990574      0.333333
# 6    1.073583       0.333333  1.060613      0.333333
# 7    1.121106       0.333333  1.121106      0.333333
# 8    1.113064       0.333333  1.113064      0.333333
# 9    1.109386       0.333333  1.109386      0.333333
# 10   1.107579       0.333333  1.107579      0.333333
# 11   1.106819       0.333333  1.106819      0.333333
# 12   1.106462       0.333333  1.106462      0.333333
# 13   1.106329       0.333333  1.106329      0.333333
# 14   1.106295       0.333333  1.106295      0.333333
# 15   1.106261       0.333333  1.106261      0.333333
# ...

# %% [markdown]
# ### Experiement Out-C-10.txt

# %%
net10 = network.loadNetwork("iris4-20-7-3.dat")
net10.set_compileParameters(regularization = 'L1', lmbda = 1.0, dropoutPercent = 0.3)
net10.set_modelParameters(cost=CrossEntropyCost, actHidden=Sigmoid, actOutput=Softmax)
trainCost, trainAccuracy, testCost, testAccuracy = \
    net10.SGD(irisTrain, 30, 8, 0.1, testData=irisTest)

displayResults(trainCost, trainAccuracy, testCost, testAccuracy)
# Out:
# Training 30 epochs complete.
#     trainCost  trainAccuracy  testCost  testAccuracy
# 0    2.415804       0.333333  3.058295      0.333333
# 1    2.387407       0.333333  2.993503      0.333333
# 2    2.368897       0.333333  2.940637      0.333333
# 3    2.349791       0.333333  2.888622      0.333333
# 4    2.331234       0.333333  2.837153      0.333333
# 5    2.312455       0.333333  2.790656      0.333333
# 6    2.294809       0.333333  2.747195      0.333333
# 7    2.250965       0.333333  2.676833      0.333333
# 8    2.245142       0.333333  2.648304      0.333333
# 9    2.215138       0.333333  2.596168      0.333333
# 10   2.216746       0.333333  2.575572      0.333333
# 11   2.196496       0.333333  2.534059      0.333333
# 12   2.162624       0.333333  2.478887      0.333333
# 13   2.152050       0.333333  2.449618      0.333333
# 14   2.140314       0.333333  2.418554      0.333333
# 15   2.133473       0.333333  2.396584      0.333333
# ...
